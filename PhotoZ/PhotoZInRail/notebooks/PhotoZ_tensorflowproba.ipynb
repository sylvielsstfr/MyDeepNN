# %% [markdown]
# ##  PhotoZ estimation :Perform a DNN regression using tensorflow probability

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os,sys
import h5py

# %%
import tensorflow as tf
from tensorflow import keras
# Out:
# 2023-04-28 18:12:28.005976: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def get_stats(z_spec,z_phot,slope=0.15):
    """
    input : 
       - z_spec : spectroscopic redshift or true redshift
       - z_phot : photo-z reedshift
       - slope : slope of line defining the outliers  3 x sigma_z with sigma_z = 5%, so slope = 3 x 0.05 = 0.15 
    """
    
    mask = np.abs((z_phot - z_spec)/(1 + z_spec)) > slope
    notmask = ~mask 
    
    # Standard Deviation of the predicted redshifts compared to the data:
    #-----------------------------------------------------------------
    std_result = np.std((z_phot - z_spec)/(1 + z_spec), ddof=1)
    print('Standard Deviation: %6.4f' % std_result)
    

    # Normalized MAD (Median Absolute Deviation):
    #------------------------------------------
    nmad = 1.48 * np.median(np.abs((z_phot - z_spec)/(1 + z_spec)))
    print('Normalized MAD: %6.4f' % nmad)

    # Percentage of delta-z > 0.15(1+z) outliers:
    #-------------------------------------------
    eta = np.sum(np.abs((z_phot - z_spec)/(1 + z_spec)) > 0.15)/len(z_spec)
    print('Delta z >0.15(1+z) outliers: %6.3f percent' % (100.*eta))
    
    # Median offset (normalized by (1+z); i.e., bias:
    #-----------------------------------------------
    bias = np.median(((z_phot - z_spec)/(1 + z_spec)))
    sigbias=std_result/np.sqrt(0.64*len(z_phot))
    print('Median offset: %6.3f +/- %6.3f' % (bias,sigbias))
    
    
     # overlay statistics with titles left-aligned and numbers right-aligned
    stats_txt = '\n'.join([
        'NMAD  = {:0.2f}'.format(nmad),
        'STDEV = {:0.2f}'.format(std_result),
        'BIAS  = {:0.2f}'.format(bias),
        'ETA   = {:0.2f}'.format(eta)
    ])
    return nmad,std_result,bias,eta,stats_txt

# %% [markdown]
# # Prepare data

# %%
input_train_file_h5 = "../data/test_dc2_training_9816.hdf5"
input_test_file_h5 = "../data/test_dc2_validation_9816.hdf5"

# %%
hftrain =  h5py.File(input_train_file_h5, 'r') 
hftest =  h5py.File(input_test_file_h5, 'r')

# %%
def getdata(hf):
    key_sel = list(hf.keys())[0]
    group = hf.get(key_sel)
    
    mag_err_u_lsst = np.array(group.get("mag_err_u_lsst"))
    mag_err_g_lsst = np.array(group.get("mag_err_g_lsst"))
    mag_err_r_lsst = np.array(group.get("mag_err_r_lsst"))
    mag_err_i_lsst = np.array(group.get("mag_err_i_lsst"))
    mag_err_z_lsst = np.array(group.get("mag_err_z_lsst"))
    mag_err_y_lsst = np.array(group.get("mag_err_y_lsst"))
    mag_u_lsst =  np.array(group.get("mag_u_lsst"))
    mag_g_lsst =  np.array(group.get("mag_g_lsst"))
    mag_r_lsst =  np.array(group.get("mag_r_lsst"))
    mag_i_lsst =  np.array(group.get("mag_i_lsst"))
    mag_z_lsst =  np.array(group.get("mag_z_lsst"))
    mag_y_lsst =  np.array(group.get("mag_y_lsst"))
    redshift = np.array(group.get("redshift"))
    
    data = np.vstack((mag_u_lsst, 
                    mag_g_lsst, 
                    mag_r_lsst, 
                    mag_i_lsst, 
                    mag_z_lsst,
                    mag_y_lsst,
                    redshift)) 
    data = data.T
    indexes_bad = np.where(data[:,0]>40)[0]
    datacut = np.delete(data,indexes_bad,axis=0)
    features = datacut[:,0:-1]
    targets = datacut[:,-1]
    return features,targets

# %%
def getdataerror(hf):
    key_sel = list(hf.keys())[0]
    group = hf.get(key_sel)
    
    mag_err_u_lsst = np.array(group.get("mag_err_u_lsst"))
    mag_err_g_lsst = np.array(group.get("mag_err_g_lsst"))
    mag_err_r_lsst = np.array(group.get("mag_err_r_lsst"))
    mag_err_i_lsst = np.array(group.get("mag_err_i_lsst"))
    mag_err_z_lsst = np.array(group.get("mag_err_z_lsst"))
    mag_err_y_lsst = np.array(group.get("mag_err_y_lsst"))
    mag_u_lsst =  np.array(group.get("mag_u_lsst"))
    mag_g_lsst =  np.array(group.get("mag_g_lsst"))
    mag_r_lsst =  np.array(group.get("mag_r_lsst"))
    mag_i_lsst =  np.array(group.get("mag_i_lsst"))
    mag_z_lsst =  np.array(group.get("mag_z_lsst"))
    mag_y_lsst =  np.array(group.get("mag_y_lsst"))
    redshift = np.array(group.get("redshift"))
    
    data = np.vstack((
                    mag_u_lsst, 
                    mag_g_lsst, 
                    mag_r_lsst, 
                    mag_i_lsst, 
                    mag_z_lsst,
                    mag_y_lsst,
                    mag_err_u_lsst, 
                    mag_err_g_lsst, 
                    mag_err_r_lsst, 
                    mag_err_i_lsst, 
                    mag_err_z_lsst,
                    mag_err_y_lsst,
                    redshift)) 
    data = data.T
    indexes_bad = np.where(data[:,0]>40)[0]
    datacut = np.delete(data,indexes_bad,axis=0)
    features = datacut[:,0:6]
    errors = datacut[:,6:-1]
    targets = datacut[:,-1]
    return features,errors,targets

# %%
x_train,y_train = getdata(hftrain)
x_test,y_test = getdata(hftest)

# %%
print('x_train : ',x_train.shape, 'y_train : ',y_train.shape)
print('x_test  : ',x_test.shape,  'y_test  : ',y_test.shape)
# Out:
# x_train :  (9511, 6) y_train :  (9511,)
# x_test  :  (18960, 6) y_test  :  (18960,)

# %%
mean = x_train.mean()
std  = x_train.std()
x_train = (x_train - mean) / std
x_test  = (x_test  - mean) / std

x_train, y_train = np.array(x_train), np.array(y_train)
x_test,  y_test  = np.array(x_test),  np.array(y_test)

# %% [markdown]
# # Standard Fit

# %%
fit_verbosity = 1

# %%
def get_model_v1(shape):
  
  model = keras.models.Sequential()
  model.add(keras.layers.Input(shape, name="InputLayer"))
  model.add(keras.layers.Dense(64, activation='relu', name='Dense_n1'))
  model.add(keras.layers.Dense(64, activation='relu', name='Dense_n2'))
  model.add(keras.layers.Dense(1, name='Output'))

  model.compile(optimizer = 'rmsprop',
                loss      = 'mse',
                metrics   = ['mae', 'mse'] )
  return model

# %%
model=get_model_v1( (6,) )

model.summary()
# img=keras.utils.plot_model( model, to_file='./run/model.png', show_shapes=True, show_layer_names=True, dpi=96)
# display(img)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_n1 (Dense)            (None, 64)                448
#
#  Dense_n2 (Dense)            (None, 64)                4160
#
#  Output (Dense)              (None, 1)                 65
#
# =================================================================
# Total params: 4,673
# Trainable params: 4,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
os.makedirs('./run/models',   mode=0o750, exist_ok=True)
save_dir = "./run/models/best_model.h5"

savemodel_callback = tf.keras.callbacks.ModelCheckpoint(filepath=save_dir, verbose=0, save_best_only=True)

# %%
history = model.fit(x_train,
                    y_train,
                    epochs          = 100,
                    batch_size      = 10,
                    verbose         = fit_verbosity,
                    validation_data = (x_test, y_test),
                    callbacks       = [savemodel_callback])
# Out:
# Epoch 1/100
# 952/952 [==============================] - 3s 3ms/step - loss: 0.1126 - mae: 0.1902 - mse: 0.1126 - val_loss: 0.0605 - val_mae: 0.1864 - val_mse: 0.0605
# Epoch 2/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0439 - mae: 0.1298 - mse: 0.0439 - val_loss: 0.0405 - val_mae: 0.1381 - val_mse: 0.0405
# Epoch 3/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0329 - mae: 0.1172 - mse: 0.0329 - val_loss: 0.0323 - val_mae: 0.1072 - val_mse: 0.0323
# Epoch 4/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0295 - mae: 0.1086 - mse: 0.0295 - val_loss: 0.0326 - val_mae: 0.1209 - val_mse: 0.0326
# Epoch 5/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0280 - mae: 0.1029 - mse: 0.0280 - val_loss: 0.0371 - val_mae: 0.1140 - val_mse: 0.0371
# Epoch 6/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0246 - mae: 0.0976 - mse: 0.0246 - val_loss: 0.0263 - val_mae: 0.0992 - val_mse: 0.0263
# Epoch 7/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0237 - mae: 0.0929 - mse: 0.0237 - val_loss: 0.0227 - val_mae: 0.0882 - val_mse: 0.0227
# Epoch 8/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0228 - mae: 0.0894 - mse: 0.0228 - val_loss: 0.0208 - val_mae: 0.0833 - val_mse: 0.0208
# Epoch 9/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0218 - mae: 0.0864 - mse: 0.0218 - val_loss: 0.0240 - val_mae: 0.0947 - val_mse: 0.0240
# Epoch 10/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0218 - mae: 0.0849 - mse: 0.0218 - val_loss: 0.0269 - val_mae: 0.1120 - val_mse: 0.0269
# Epoch 11/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0201 - mae: 0.0826 - mse: 0.0201 - val_loss: 0.0207 - val_mae: 0.0858 - val_mse: 0.0207
# Epoch 12/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0204 - mae: 0.0812 - mse: 0.0204 - val_loss: 0.0215 - val_mae: 0.0814 - val_mse: 0.0215
# Epoch 13/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0194 - mae: 0.0798 - mse: 0.0194 - val_loss: 0.0204 - val_mae: 0.0813 - val_mse: 0.0204
# Epoch 14/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0190 - mae: 0.0785 - mse: 0.0190 - val_loss: 0.0258 - val_mae: 0.1072 - val_mse: 0.0258
# Epoch 15/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0176 - mae: 0.0770 - mse: 0.0176 - val_loss: 0.0221 - val_mae: 0.0920 - val_mse: 0.0221
# Epoch 16/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0185 - mae: 0.0772 - mse: 0.0185 - val_loss: 0.0195 - val_mae: 0.0768 - val_mse: 0.0195
# Epoch 17/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0182 - mae: 0.0764 - mse: 0.0182 - val_loss: 0.0175 - val_mae: 0.0721 - val_mse: 0.0175
# Epoch 18/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0180 - mae: 0.0755 - mse: 0.0180 - val_loss: 0.0166 - val_mae: 0.0700 - val_mse: 0.0166
# Epoch 19/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0162 - mae: 0.0742 - mse: 0.0162 - val_loss: 0.0191 - val_mae: 0.0774 - val_mse: 0.0191
# Epoch 20/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0173 - mae: 0.0735 - mse: 0.0173 - val_loss: 0.0169 - val_mae: 0.0695 - val_mse: 0.0169
# Epoch 21/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0174 - mae: 0.0730 - mse: 0.0174 - val_loss: 0.0201 - val_mae: 0.0894 - val_mse: 0.0201
# Epoch 22/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0171 - mae: 0.0727 - mse: 0.0171 - val_loss: 0.0164 - val_mae: 0.0687 - val_mse: 0.0164
# Epoch 23/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0170 - mae: 0.0717 - mse: 0.0170 - val_loss: 0.0177 - val_mae: 0.0769 - val_mse: 0.0177
# Epoch 24/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0168 - mae: 0.0719 - mse: 0.0168 - val_loss: 0.0186 - val_mae: 0.0728 - val_mse: 0.0186
# Epoch 25/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0155 - mae: 0.0710 - mse: 0.0155 - val_loss: 0.0163 - val_mae: 0.0680 - val_mse: 0.0163
# Epoch 26/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0163 - mae: 0.0704 - mse: 0.0163 - val_loss: 0.0168 - val_mae: 0.0703 - val_mse: 0.0168
# Epoch 27/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0166 - mae: 0.0709 - mse: 0.0166 - val_loss: 0.0321 - val_mae: 0.1022 - val_mse: 0.0321
# Epoch 28/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0166 - mae: 0.0703 - mse: 0.0166 - val_loss: 0.0179 - val_mae: 0.0710 - val_mse: 0.0179
# Epoch 29/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0163 - mae: 0.0697 - mse: 0.0163 - val_loss: 0.0163 - val_mae: 0.0715 - val_mse: 0.0163
# Epoch 30/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0155 - mae: 0.0692 - mse: 0.0155 - val_loss: 0.0167 - val_mae: 0.0706 - val_mse: 0.0167
# Epoch 31/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0158 - mae: 0.0693 - mse: 0.0158 - val_loss: 0.0164 - val_mae: 0.0708 - val_mse: 0.0164
# Epoch 32/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0155 - mae: 0.0692 - mse: 0.0155 - val_loss: 0.0171 - val_mae: 0.0783 - val_mse: 0.0171
# Epoch 33/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0162 - mae: 0.0683 - mse: 0.0162 - val_loss: 0.0161 - val_mae: 0.0662 - val_mse: 0.0161
# Epoch 34/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0152 - mae: 0.0680 - mse: 0.0152 - val_loss: 0.0190 - val_mae: 0.0807 - val_mse: 0.0190
# Epoch 35/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0157 - mae: 0.0680 - mse: 0.0157 - val_loss: 0.0171 - val_mae: 0.0720 - val_mse: 0.0171
# Epoch 36/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0151 - mae: 0.0678 - mse: 0.0151 - val_loss: 0.0197 - val_mae: 0.0826 - val_mse: 0.0197
# Epoch 37/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0158 - mae: 0.0681 - mse: 0.0158 - val_loss: 0.0157 - val_mae: 0.0664 - val_mse: 0.0157
# Epoch 38/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0149 - mae: 0.0677 - mse: 0.0149 - val_loss: 0.0193 - val_mae: 0.0780 - val_mse: 0.0193
# Epoch 39/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0153 - mae: 0.0681 - mse: 0.0153 - val_loss: 0.0169 - val_mae: 0.0723 - val_mse: 0.0169
# Epoch 40/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0152 - mae: 0.0672 - mse: 0.0152 - val_loss: 0.0203 - val_mae: 0.0774 - val_mse: 0.0203
# Epoch 41/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0148 - mae: 0.0676 - mse: 0.0148 - val_loss: 0.0228 - val_mae: 0.0872 - val_mse: 0.0228
# Epoch 42/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0151 - mae: 0.0672 - mse: 0.0151 - val_loss: 0.0160 - val_mae: 0.0675 - val_mse: 0.0160
# Epoch 43/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0153 - mae: 0.0666 - mse: 0.0153 - val_loss: 0.0162 - val_mae: 0.0678 - val_mse: 0.0162
# Epoch 44/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0155 - mae: 0.0668 - mse: 0.0155 - val_loss: 0.0183 - val_mae: 0.0709 - val_mse: 0.0183
# Epoch 45/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0156 - mae: 0.0664 - mse: 0.0156 - val_loss: 0.0162 - val_mae: 0.0649 - val_mse: 0.0162
# Epoch 46/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0658 - mse: 0.0143 - val_loss: 0.0158 - val_mae: 0.0661 - val_mse: 0.0158
# Epoch 47/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0145 - mae: 0.0656 - mse: 0.0145 - val_loss: 0.0185 - val_mae: 0.0729 - val_mse: 0.0185
# Epoch 48/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0151 - mae: 0.0657 - mse: 0.0151 - val_loss: 0.0172 - val_mae: 0.0722 - val_mse: 0.0172
# Epoch 49/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0150 - mae: 0.0654 - mse: 0.0150 - val_loss: 0.0173 - val_mae: 0.0692 - val_mse: 0.0173
# Epoch 50/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0148 - mae: 0.0663 - mse: 0.0148 - val_loss: 0.0189 - val_mae: 0.0683 - val_mse: 0.0189
# Epoch 51/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0649 - mse: 0.0143 - val_loss: 0.0165 - val_mae: 0.0731 - val_mse: 0.0165
# Epoch 52/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0142 - mae: 0.0655 - mse: 0.0142 - val_loss: 0.0189 - val_mae: 0.0796 - val_mse: 0.0189
# Epoch 53/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0146 - mae: 0.0652 - mse: 0.0146 - val_loss: 0.0163 - val_mae: 0.0692 - val_mse: 0.0163
# Epoch 54/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0144 - mae: 0.0652 - mse: 0.0144 - val_loss: 0.0171 - val_mae: 0.0730 - val_mse: 0.0171
# Epoch 55/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0150 - mae: 0.0647 - mse: 0.0150 - val_loss: 0.0159 - val_mae: 0.0639 - val_mse: 0.0159
# Epoch 56/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0145 - mae: 0.0651 - mse: 0.0145 - val_loss: 0.0160 - val_mae: 0.0660 - val_mse: 0.0160
# Epoch 57/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0146 - mae: 0.0651 - mse: 0.0146 - val_loss: 0.0170 - val_mae: 0.0712 - val_mse: 0.0170
# Epoch 58/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0139 - mae: 0.0644 - mse: 0.0139 - val_loss: 0.0155 - val_mae: 0.0639 - val_mse: 0.0155
# Epoch 59/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0649 - mse: 0.0143 - val_loss: 0.0158 - val_mae: 0.0641 - val_mse: 0.0158
# Epoch 60/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0146 - mae: 0.0647 - mse: 0.0146 - val_loss: 0.0158 - val_mae: 0.0642 - val_mse: 0.0158
# Epoch 61/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0141 - mae: 0.0644 - mse: 0.0141 - val_loss: 0.0173 - val_mae: 0.0739 - val_mse: 0.0173
# Epoch 62/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0639 - mse: 0.0143 - val_loss: 0.0164 - val_mae: 0.0639 - val_mse: 0.0164
# Epoch 63/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0145 - mae: 0.0640 - mse: 0.0145 - val_loss: 0.0157 - val_mae: 0.0650 - val_mse: 0.0157
# Epoch 64/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0136 - mae: 0.0639 - mse: 0.0136 - val_loss: 0.0169 - val_mae: 0.0678 - val_mse: 0.0169
# Epoch 65/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0644 - mse: 0.0143 - val_loss: 0.0175 - val_mae: 0.0765 - val_mse: 0.0175
# Epoch 66/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0150 - mae: 0.0639 - mse: 0.0150 - val_loss: 0.0156 - val_mae: 0.0655 - val_mse: 0.0156
# Epoch 67/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0139 - mae: 0.0637 - mse: 0.0139 - val_loss: 0.0161 - val_mae: 0.0689 - val_mse: 0.0161
# Epoch 68/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0133 - mae: 0.0642 - mse: 0.0133 - val_loss: 0.0155 - val_mae: 0.0650 - val_mse: 0.0155
# Epoch 69/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0142 - mae: 0.0634 - mse: 0.0142 - val_loss: 0.0209 - val_mae: 0.0690 - val_mse: 0.0209
# Epoch 70/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0143 - mae: 0.0640 - mse: 0.0143 - val_loss: 0.0166 - val_mae: 0.0682 - val_mse: 0.0166
# Epoch 71/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0140 - mae: 0.0640 - mse: 0.0140 - val_loss: 0.0160 - val_mae: 0.0687 - val_mse: 0.0160
# Epoch 72/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0132 - mae: 0.0631 - mse: 0.0132 - val_loss: 0.0157 - val_mae: 0.0671 - val_mse: 0.0157
# Epoch 73/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0132 - mae: 0.0634 - mse: 0.0132 - val_loss: 0.0168 - val_mae: 0.0652 - val_mse: 0.0168
# Epoch 74/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0139 - mae: 0.0641 - mse: 0.0139 - val_loss: 0.0157 - val_mae: 0.0648 - val_mse: 0.0157
# Epoch 75/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0131 - mae: 0.0636 - mse: 0.0131 - val_loss: 0.0196 - val_mae: 0.0756 - val_mse: 0.0196
# Epoch 76/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0137 - mae: 0.0639 - mse: 0.0137 - val_loss: 0.0148 - val_mae: 0.0624 - val_mse: 0.0148
# Epoch 77/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0137 - mae: 0.0637 - mse: 0.0137 - val_loss: 0.0162 - val_mae: 0.0720 - val_mse: 0.0162
# Epoch 78/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0139 - mae: 0.0633 - mse: 0.0139 - val_loss: 0.0157 - val_mae: 0.0630 - val_mse: 0.0157
# Epoch 79/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0142 - mae: 0.0635 - mse: 0.0142 - val_loss: 0.0176 - val_mae: 0.0808 - val_mse: 0.0176
# Epoch 80/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0134 - mae: 0.0630 - mse: 0.0134 - val_loss: 0.0170 - val_mae: 0.0684 - val_mse: 0.0170
# Epoch 81/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0147 - mae: 0.0633 - mse: 0.0147 - val_loss: 0.0161 - val_mae: 0.0677 - val_mse: 0.0161
# Epoch 82/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0135 - mae: 0.0628 - mse: 0.0135 - val_loss: 0.0194 - val_mae: 0.0673 - val_mse: 0.0194
# Epoch 83/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0135 - mae: 0.0630 - mse: 0.0135 - val_loss: 0.0161 - val_mae: 0.0647 - val_mse: 0.0161
# Epoch 84/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0134 - mae: 0.0626 - mse: 0.0134 - val_loss: 0.0168 - val_mae: 0.0705 - val_mse: 0.0168
# Epoch 85/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0130 - mae: 0.0623 - mse: 0.0130 - val_loss: 0.0162 - val_mae: 0.0635 - val_mse: 0.0162
# Epoch 86/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0137 - mae: 0.0628 - mse: 0.0137 - val_loss: 0.0157 - val_mae: 0.0663 - val_mse: 0.0157
# Epoch 87/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0138 - mae: 0.0624 - mse: 0.0138 - val_loss: 0.0173 - val_mae: 0.0720 - val_mse: 0.0173
# Epoch 88/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0132 - mae: 0.0621 - mse: 0.0132 - val_loss: 0.0160 - val_mae: 0.0646 - val_mse: 0.0160
# Epoch 89/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0137 - mae: 0.0620 - mse: 0.0137 - val_loss: 0.0207 - val_mae: 0.0740 - val_mse: 0.0207
# Epoch 90/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0136 - mae: 0.0626 - mse: 0.0136 - val_loss: 0.0169 - val_mae: 0.0663 - val_mse: 0.0169
# Epoch 91/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0144 - mae: 0.0627 - mse: 0.0144 - val_loss: 0.0174 - val_mae: 0.0629 - val_mse: 0.0174
# Epoch 92/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0134 - mae: 0.0621 - mse: 0.0134 - val_loss: 0.0179 - val_mae: 0.0695 - val_mse: 0.0179
# Epoch 93/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0132 - mae: 0.0616 - mse: 0.0132 - val_loss: 0.0191 - val_mae: 0.0666 - val_mse: 0.0191
# Epoch 94/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0138 - mae: 0.0621 - mse: 0.0138 - val_loss: 0.0176 - val_mae: 0.0735 - val_mse: 0.0176
# Epoch 95/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0136 - mae: 0.0618 - mse: 0.0136 - val_loss: 0.0184 - val_mae: 0.0649 - val_mse: 0.0184
# Epoch 96/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0135 - mae: 0.0617 - mse: 0.0135 - val_loss: 0.0161 - val_mae: 0.0683 - val_mse: 0.0161
# Epoch 97/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0136 - mae: 0.0611 - mse: 0.0136 - val_loss: 0.0170 - val_mae: 0.0686 - val_mse: 0.0170
# Epoch 98/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0133 - mae: 0.0612 - mse: 0.0133 - val_loss: 0.0155 - val_mae: 0.0677 - val_mse: 0.0155
# Epoch 99/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0128 - mae: 0.0610 - mse: 0.0128 - val_loss: 0.0183 - val_mae: 0.0690 - val_mse: 0.0183
# Epoch 100/100
# 952/952 [==============================] - 2s 2ms/step - loss: 0.0135 - mae: 0.0616 - mse: 0.0135 - val_loss: 0.0164 - val_mae: 0.0651 - val_mse: 0.0164

# %%
score = model.evaluate(x_test, y_test, verbose=0)

print('x_test / loss      : {:5.4f}'.format(score[0]))
print('x_test / mae       : {:5.4f}'.format(score[1]))
print('x_test / mse       : {:5.4f}'.format(score[2]))
# Out:
# x_test / loss      : 0.0164
# x_test / mae       : 0.0651
# x_test / mse       : 0.0164

# %%
df = pd.DataFrame(history.history)

# %%
df
# Out:
#         loss       mae       mse  val_loss   val_mae   val_mse
# 0   0.112617  0.190191  0.112617  0.060514  0.186404  0.060514
# 1   0.043868  0.129790  0.043868  0.040486  0.138061  0.040486
# 2   0.032934  0.117235  0.032934  0.032299  0.107186  0.032299
# 3   0.029474  0.108625  0.029474  0.032624  0.120922  0.032624
# 4   0.027987  0.102948  0.027987  0.037111  0.113991  0.037111
# ..       ...       ...       ...       ...       ...       ...
# 95  0.013516  0.061664  0.013516  0.016132  0.068273  0.016132
# 96  0.013573  0.061112  0.013573  0.017018  0.068586  0.017018
# 97  0.013256  0.061201  0.013256  0.015468  0.067720  0.015468
# 98  0.012754  0.061006  0.012754  0.018343  0.068988  0.018343
# 99  0.013539  0.061639  0.013539  0.016377  0.065101  0.016377
#
# [100 rows x 6 columns]

# %%
loaded_model = tf.keras.models.load_model('./run/models/best_model.h5')
loaded_model.summary()
print("Loaded.")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Dense_n1 (Dense)            (None, 64)                448
#
#  Dense_n2 (Dense)            (None, 64)                4160
#
#  Output (Dense)              (None, 1)                 65
#
# =================================================================
# Total params: 4,673
# Trainable params: 4,673
# Non-trainable params: 0
# _________________________________________________________________
# Loaded.

# %%
score = loaded_model.evaluate(x_test, y_test, verbose=0)

print('x_test / loss      : {:5.4f}'.format(score[0]))
print('x_test / mae       : {:5.4f}'.format(score[1]))
print('x_test / mse       : {:5.4f}'.format(score[2]))
# Out:
# x_test / loss      : 0.0148
# x_test / mae       : 0.0624
# x_test / mse       : 0.0148

# %%
my_data=x_test

# %%
predictions = loaded_model.predict( my_data )
# Out:
# 593/593 [==============================] - 0s 715us/step

# %%
z_spec = y_test
z_phot = predictions.T

# %%
nmad,std_result,bias,eta,stats_txt = get_stats(z_spec,z_phot,slope=0.15)
# Out:
# Standard Deviation: 0.0653
# Normalized MAD: 0.0284
# Delta z >0.15(1+z) outliers:  2.220 percent
# Median offset:  0.003 +/-  0.082

# %%
# these are matplotlib.patch.Patch properties
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
# place a text box in upper left in axes coords

# %%
def plot_lines(zmin=0,zmax=3,zstep=0.05,slope=0.15):
    x = np.arange(zmin,zmax,zstep)
    outlier_upper = x + slope*(1+x)
    outlier_lower = x - slope*(1+x)
    return x,outlier_upper,outlier_lower

# %%
x,outlier_upper,outlier_lower = plot_lines(zmin=0,zmax=3,zstep=0.05,slope=0.15)

# %%
fig=plt.figure(figsize=(10,10))
ax=fig.add_subplot(1,1,1)
ax.scatter(z_spec,z_phot,marker='.',s=5,alpha=0.1)
ax.text(0.05, 0.95, stats_txt, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)
ax.set_xlabel("$z_{spec}$ (true target value)")
ax.set_ylabel("$z_{phot}$ (predicted target value)")
ax.set_title("DNN (optim model): photometric redshift vs spectroscopic redshift")
ax.plot(x,outlier_upper,'k:')
ax.plot(x,outlier_lower,'k:')

# %% [markdown]
# ## In tensorflow probability
